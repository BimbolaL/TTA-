# %%
# Create a CSV file of 15 holiday destinations for a website

import pandas as pd
data = pd.read_csv("Destination_Holiday_data15.csv")

# %%
data
# Out:
#     Unnamed: 0     Destination  Feedback_Score  Hotel_Star  \
# 0            0         Nigeria              10           5
# 1            1         Nigeria               8           5
# 2            2  United Kingdom               5           4
# 3            3  United Kingdom               6           5
# 4            4    United State               5           3
# 5            5           Kenya               6           5
# 6            6          France               9           1
# 7            7         Jamaica               2           4
# 8            8          Turkey               8           2
# 9            9           Italy               8           5
# 10          10           China               6           4
# 11          11         Algeria               9           1
# 12          12          Angola               2           4
# 13          13           Benin               8           2
# 14          14        Botswana               8           5
# ...

# %%
# Task 2.
# Add in a column that shows feedback score out of 10 for that
# destination
data["Feedback_Score"] >10
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Feedback_Score, dtype: bool

# %%
# Task 3.
# Add in a column for average hotel star rating for those
# destinations
data["Hotel_Star"].mean()
# Out:
# 3.6875

# %%
# task 4.
# Add in a column for number of all-inclusive hotels within each destination
data["All_Inclusive_Hotel"].mean()
# Out:
# 15.9375

# %%
# Task 5
# Add in the most visited city in each destination
data["Most_Visted_City"].mean()
